# %% [markdown]
# <a href="https://colab.research.google.com/github/itssraj/sfguide-data-engineering-with-notebooks/blob/main/Target_Imbalance_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount our google drive space
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

dataset=pd.read_csv("/content/drive/MyDrive/Churn_Banking_Modeling_ENG.csv", sep=",")

# %%
dataset
# Out:
#         customer_id flag_request_closure  amt_cust_value  \
# 0                 2                   no           65.03
# 1                 3                   no          138.88
# 2                 4                   no          546.54
# 3                 5                   no           68.69
# 4                 7                   no         2417.05
# ...             ...                  ...             ...
# 377364       555146                   no         5317.47
# 377365       555147                   no           17.35
# 377366       555148                   no          334.73
# 377367       555149                   no         5171.38
# 377368       555150                   no           68.10
#
#         flag_online_acc_opening  flag_mult_account_ownership  num_age  \
# 0                             0                            0     38.0
# 1                             0                            0     45.0
# ...

# %%
dataset = dataset.rename(columns= {'flag_request_closure': 'Target'})

# %%
dataset.replace({'Target':{"si":1}},inplace=True)
dataset.replace({'Target':{"no":0}},inplace=True)
# Out:
# /tmp/ipython-input-979450243.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset.replace({'Target':{"no":0}},inplace=True)

# %%
dataset
# Out:
#         customer_id  Target  amt_cust_value  flag_online_acc_opening  \
# 0                 2       0           65.03                        0
# 1                 3       0          138.88                        0
# 2                 4       0          546.54                        0
# 3                 5       0           68.69                        0
# 4                 7       0         2417.05                        0
# ...             ...     ...             ...                      ...
# 377364       555146       0         5317.47                        1
# 377365       555147       0           17.35                        0
# 377366       555148       0          334.73                        0
# 377367       555149       0         5171.38                        0
# 377368       555150       0           68.10                        0
#
#         flag_mult_account_ownership  num_age str_prov_domicile  \
# 0                                 0     38.0                BO
# ...

# %%
display(dataset.columns);
# Out:
# Index(['customer_id', 'Target', 'amt_cust_value', 'flag_online_acc_opening',
#        'flag_mult_account_ownership', 'num_age', 'str_prov_domicile',
#        'str_prov_residence', 'num_year_first_account', 'str_profession',
#        'amt_income', 'str_cust_type', 'str_gender', 'Profilo_MIFID',
#        'amt_pricing_fee', 'amt_transfer_vs_competitors',
#        'amt_tranfers_vs_no_competitors', 'num_existing_services',
#        'flag_salary_deposit', 'amt_credit_card_spending',
#        'amt_debit_card_spending', 'num_website_access_count',
#        'num_transactions_count', 'num_trading_activities_count',
#        'str_change_num_utilities', 'flag_mortgage', 'flag_loan',
#        'flag_internal_tranfers', 'flag_request_info_closure',
#        'flag_loyalty_program_enrol', 'flag_call_center_contact',
#        'flag_salary_deposit_variation', 'num_loyalty_points',
#        'amt_current_liquidity', 'amt_current_managed',
#        'amt_current_administered', 'amt_6m_current_liquidity',
# ...

# %%
# for sake of simplicity
# Chose to work on numerical variables

var_to_use = ['Target', 'amt_cust_value', 'flag_online_acc_opening',
       'flag_mult_account_ownership', 'num_age',
        'num_year_first_account',
        'amt_pricing_fee', 'amt_transfer_vs_competitors',
       'amt_tranfers_vs_no_competitors', 'num_existing_services',
       'flag_salary_deposit', 'amt_credit_card_spending',
       'amt_debit_card_spending', 'num_website_access_count',
       'num_transactions_count', 'num_trading_activities_count',
       'str_change_num_utilities', 'flag_mortgage', 'flag_loan',
       'flag_internal_tranfers', 'flag_request_info_closure',
       'flag_loyalty_program_enrol', 'flag_call_center_contact',
       'flag_salary_deposit_variation', 'num_loyalty_points',
       'amt_current_liquidity', 'amt_current_managed',
       'amt_current_administered', 'amt_6m_current_liquidity',
       'amt_6m_current_managed', 'amt_6m_current_administered',
       'flag_outgoing_sec_tranfer', 'flag_card_rejection',
       'flag_loan_rejection', 'flag_deactivation_rid']

# %%
features_names = var_to_use.copy()
features_names.remove('Target')

# %%
dataset = dataset[var_to_use].copy()

# %%
dataset
# Out:
#         Target  amt_cust_value  flag_online_acc_opening  \
# 0            0           65.03                        0
# 1            0          138.88                        0
# 2            0          546.54                        0
# 3            0           68.69                        0
# 4            0         2417.05                        0
# ...        ...             ...                      ...
# 377364       0         5317.47                        1
# 377365       0           17.35                        0
# 377366       0          334.73                        0
# 377367       0         5171.38                        0
# 377368       0           68.10                        0
#
#         flag_mult_account_ownership  num_age  num_year_first_account  \
# 0                                 0     38.0                  2004.0
# 1                                 0     45.0                  2000.0
# 2                                 0     61.0                  2005.0
# ...

# %%
# impute all missing values to zero

dataset[features_names] = dataset[features_names].fillna(0)

# %%
# create the features dataframe with just feature  variables (remove target)
# use drop method

features = dataset.drop('Target', axis = 1)

# %%
# creata the array for target variables
target = dataset[['Target']].values

# %%
# train and test split
# in order to prevent overfitting

from sklearn.model_selection import train_test_split

(train_X, test_X, train_y, test_y) = train_test_split(features, target, train_size=0.7, random_state= 1)

# %%
from collections import Counter
print("train target count : ", Counter(train_y[:,0]))
# Out:
# train target count :  Counter({np.int64(0): 262759, np.int64(1): 1399})

# %%
# train the model

from sklearn.tree import DecisionTreeClassifier
# instantiate the classifier
dtc = DecisionTreeClassifier(random_state=1)
# fit the model
dtc.fit(train_X, train_y)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
# predict the model based on test data
label_pred_test = dtc.predict(test_X)
score_test = dtc.predict_proba(test_X)

# predict the model based on train data
label_pred_train = dtc.predict(train_X)
score_train = dtc.predict_proba(train_X)

# %%
# confusion matrix to compare the predicted results again the real dataset

from sklearn.metrics import confusion_matrix
cm_test = confusion_matrix(test_y, label_pred_test)
print(cm_test)
# Out:
# [[111944    683]
#  [   527     57]]

# %%
from sklearn.metrics import confusion_matrix
cm_train = confusion_matrix(train_y, label_pred_train)
print(cm_train)
# Out:
# [[262759      0]
#  [     2   1397]]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(test_y, label_pred_test))
# Out:
# 0.9893119926508908

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(train_y, label_pred_train))
# Out:
# 0.9999924287736884

# %%
from sklearn import tree
import graphviz

dot_data = tree.export_graphviz(dtc, out_file=None,
                                feature_names=features_names,
                                class_names=['no', 'si'],
                                filled=True)
graph = graphviz.Source(dot_data)
#graph.render("dtc")
graph

# %%
dtc.get_depth()
dtc_leaves = dtc.get_n_leaves
dtc_leaves
# Out:
# <bound method BaseDecisionTree.get_n_leaves of DecisionTreeClassifier(random_state=1)>

# %%
# Choose to perfrom undersampling
# install package for imbalanced-learn

from imblearn.under_sampling import RandomUnderSampler
# choose to set 20% as undersampling percentage

undersample = RandomUnderSampler(sampling_strategy=0.2, random_state=1)
# generate balanced train dataset
train_X_bal2, train_y_bal2 = undersample.fit_resample(train_X, train_y)

# %%
# retrain the model

from sklearn.tree import DecisionTreeClassifier
# instantiate the classifier
dtc2 = DecisionTreeClassifier(random_state=1)
# fit the model
dtc2.fit(train_X_bal2, train_y_bal2)
#
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
# predict the model based on retrained test data

label_pred_test2 = dtc2.predict(train_X_bal2)
score_test2 = dtc2.predict_proba(train_X_bal2)

# %%
from sklearn.tree import DecisionTreeClassifier
# instantiate the classifier
dtc3 = DecisionTreeClassifier(max_depth=7)
# fit the model
dtc3.fit(train_X_bal2, train_y_bal2)
# Out:
# DecisionTreeClassifier(max_depth=7)

# %%
label_pred_test3 = dtc3.predict(test_X)
score_test3 = dtc3.predict_proba(test_X)

# %%
from sklearn.metrics import confusion_matrix
cm_test = confusion_matrix(test_y, label_pred_test3)
print(cm_test)
# Out:
# [[106517   6110]
#  [   302    282]]
